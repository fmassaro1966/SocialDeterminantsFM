# %%
def yourFunction(x):
       return x*x

#df_squared = df.apply.map(yourFunction)
#!/usr/bin/env python3
def yourFunction(x):
       return x*x
     
#df is your dataframe
#example function is applicable for all INT dataframe 
#df_squared = df.apply(yourFunction)

# %%
import pandas as pd     
import matplotlib.pyplot as plt
import seaborn as sns
# import numpy as np as np

# %%
# pd.set_option(display.max_rows, None)
# pd.set_option('display.max_columns', None)
# pd.set_option('display.width', None)

# %%
df=pd.read_csv('FMsocial-deter.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df=pd.read_csv('FMsocial-deter.csv')
#
# File c:\Users\Francine\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
print(df.shape)
df.head(10)
# Out:
# (3144, 158)
#    ST    STATE ST_ABBR  STCNTY           COUNTY  FIPS  \
# 0   1  Alabama      AL    1001   Autauga County  1001
# 1   1  Alabama      AL    1003   Baldwin County  1003
# 2   1  Alabama      AL    1005   Barbour County  1005
# 3   1  Alabama      AL    1007      Bibb County  1007
# 4   1  Alabama      AL    1009    Blount County  1009
# 5   1  Alabama      AL    1011   Bullock County  1011
# 6   1  Alabama      AL    1013    Butler County  1013
# 7   1  Alabama      AL    1015   Calhoun County  1015
# 8   1  Alabama      AL    1017  Chambers County  1017
# 9   1  Alabama      AL    1019  Cherokee County  1019
#
#                    LOCATION    AREA_SQMI  E_TOTPOP  M_TOTPOP  ...  EP_ASIAN  \
# 0   Autauga County, Alabama   594.454786     58761         0  ...       1.1
# 1   Baldwin County, Alabama  1589.861817    233420         0  ...       0.9
# 2   Barbour County, Alabama   885.007619     24877         0  ...       0.5
# ...

# %%
df.dtypes
df.describe()
# Out:
#                 ST        STCNTY          FIPS      AREA_SQMI      E_TOTPOP  \
# count  3144.000000   3144.000000   3144.000000    3144.000000  3.144000e+03
# mean     30.264313  30368.187023  30368.187023    1123.812856  1.053109e+05
# std      15.152668  15170.427484  15170.427484    3592.773606  3.337924e+05
# min       1.000000   1001.000000   1001.000000       2.046442  5.000000e+01
# 25%      18.000000  18174.500000  18174.500000     430.968649  1.083575e+04
# 50%      29.000000  29174.000000  29174.000000     615.625786  2.578450e+04
# 75%      45.000000  45079.500000  45079.500000     924.245980  6.807975e+04
# max      56.000000  56045.000000  56045.000000  145575.491748  9.936690e+06
#
#           M_TOTPOP          E_HU         M_HU          E_HH         M_HH  ...  \
# count  3144.000000  3.144000e+03  3144.000000  3.144000e+03  3144.000000  ...
# mean      5.687023  4.482939e+04    66.367366  3.999248e+04   378.694975  ...
# ...

# %%
df.isna()
df.isna().sum()
# Out:
# ST              0
# STATE           0
# ST_ABBR         0
# STCNTY          0
# COUNTY          0
#                ..
# MP_NHPI         0
# EP_TWOMORE      0
# MP_TWOMORE      0
# EP_OTHERRACE    0
# MP_OTHERRACE    0
# Length: 158, dtype: int64

# %%
df.duplicated(keep=False).sum()
# Out:
# np.int64(0)

# %%
import numpy as np # pyright: ignore[reportMissingImports]

# %%
# df = pd.read_csv('C:\Users\Francine\Desktop\Code You\Capstone\FrancineMassaro_socialdet.csv.csv')

# Ensure only numeric columns are used for histogram calculations
numeric_columns = df.select_dtypes(include='[0-1009float64, int64]')


# Plot histogram of the differences for numeric columns only
diff_df = numeric_columns.diff().dropna()
plt.figure(figsize=(10, 5))
diff_df.hist(bins=60, alpha=0.7)
plt.xlabel('Difference')
plt.ylabel('Frequency')
plt.suptitle('Histogram of Differences for Numeric Columns')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 8
#       2 import matplotlib.pyplot as plt
#       4 # Sample DataFrame creation (replace this with your actual df)
#       5 # df = pd.read_csv('your_file.csv')
#       6
#       7 # Ensure only numeric columns are used for histogram calculations
# ----> 8 numeric_columns = df.select_dtypes(include='number')
#      11 # Plot histogram of the differences for numeric columns only
#      12 diff_df = numeric_columns.diff().dropna()
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Sample DataFrame for demonstration
# Replace this with your actual DataFrame
data = {
    'M_NOVEH': [5, 10, 15, 20, 25, 30, 35],
    'M_NOINT': [3, 8, 14, 18, 24, 28, 33]
}
df = pd.DataFrame(data)

# Create figure with specific size
plt.figure(figsize=(12, 6))

# Scatter plot with '+' markers and dashed line
plt.plot(
    df['M_NOVEH'],
    df['M_NOINT'],
    marker='+',
    linestyle='--',
    color='#37BA26',
    linewidth=0.5
)

# Axis labels and title
plt.xlabel("Households with no vehicle available (%)", fontsize=12)
plt.ylabel("Households with no internet access (%)", fontsize=12)
plt.title("Correlation between No Vehicle Availability and No Internet Access", fontsize=18, pad=20)

# Get current axes and customize spines
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Add vertical line at mean of M_NOVEH
mean_x = df['M_NOVEH'].mean()
mean_y = df['M_NOINT'].mean()
ax.axvline(
    mean_x,
    color="#37BA26BA",
    linewidth=0.5,
    alpha=0.7
)

# Annotate the mean
ax.text(
    mean_x + 0.5, 
    mean_y,
    "Mean",
    color="#37BA26BA",
    fontsize=10
)

# Optional: add grid for better readability
ax.grid(True, linestyle='--', alpha=0.3)


# Show the plot
plt.show()
